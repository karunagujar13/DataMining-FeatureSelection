# %%
import pandas as pd
import statistics 
import math
from scipy import stats
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df_iris=pd.read_csv(r'iris.data')
df_iris.columns =['sepal_len', 'sepal_width', 'petal_len', 'petal_width','label']

# %%
df_iris
# Out:
#      sepal_len  sepal_width  petal_len  petal_width           label
# 0          4.9          3.0        1.4          0.2     Iris-setosa
# 1          4.7          3.2        1.3          0.2     Iris-setosa
# 2          4.6          3.1        1.5          0.2     Iris-setosa
# 3          5.0          3.6        1.4          0.2     Iris-setosa
# 4          5.4          3.9        1.7          0.4     Iris-setosa
# ..         ...          ...        ...          ...             ...
# 144        6.7          3.0        5.2          2.3  Iris-virginica
# 145        6.3          2.5        5.0          1.9  Iris-virginica
# 146        6.5          3.0        5.2          2.0  Iris-virginica
# 147        6.2          3.4        5.4          2.3  Iris-virginica
# 148        5.9          3.0        5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df_setosa = df_iris[df_iris["label"]=="Iris-setosa"]

df_setosa
# Out:
#     sepal_len  sepal_width  petal_len  petal_width        label
# 0         4.9          3.0        1.4          0.2  Iris-setosa
# 1         4.7          3.2        1.3          0.2  Iris-setosa
# 2         4.6          3.1        1.5          0.2  Iris-setosa
# 3         5.0          3.6        1.4          0.2  Iris-setosa
# 4         5.4          3.9        1.7          0.4  Iris-setosa
# 5         4.6          3.4        1.4          0.3  Iris-setosa
# 6         5.0          3.4        1.5          0.2  Iris-setosa
# 7         4.4          2.9        1.4          0.2  Iris-setosa
# 8         4.9          3.1        1.5          0.1  Iris-setosa
# 9         5.4          3.7        1.5          0.2  Iris-setosa
# 10        4.8          3.4        1.6          0.2  Iris-setosa
# 11        4.8          3.0        1.4          0.1  Iris-setosa
# 12        4.3          3.0        1.1          0.1  Iris-setosa
# 13        5.8          4.0        1.2          0.2  Iris-setosa
# ...

# %%
df_versicolor = df_iris[df_iris["label"]=="Iris-versicolor"]

df_versicolor
# Out:
#     sepal_len  sepal_width  petal_len  petal_width            label
# 49        7.0          3.2        4.7          1.4  Iris-versicolor
# 50        6.4          3.2        4.5          1.5  Iris-versicolor
# 51        6.9          3.1        4.9          1.5  Iris-versicolor
# 52        5.5          2.3        4.0          1.3  Iris-versicolor
# 53        6.5          2.8        4.6          1.5  Iris-versicolor
# 54        5.7          2.8        4.5          1.3  Iris-versicolor
# 55        6.3          3.3        4.7          1.6  Iris-versicolor
# 56        4.9          2.4        3.3          1.0  Iris-versicolor
# 57        6.6          2.9        4.6          1.3  Iris-versicolor
# 58        5.2          2.7        3.9          1.4  Iris-versicolor
# 59        5.0          2.0        3.5          1.0  Iris-versicolor
# 60        5.9          3.0        4.2          1.5  Iris-versicolor
# 61        6.0          2.2        4.0          1.0  Iris-versicolor
# ...

# %%
df_virginica = df_iris[df_iris["label"]=="Iris-virginica"]

df_virginica
# Out:
#      sepal_len  sepal_width  petal_len  petal_width           label
# 99         6.3          3.3        6.0          2.5  Iris-virginica
# 100        5.8          2.7        5.1          1.9  Iris-virginica
# 101        7.1          3.0        5.9          2.1  Iris-virginica
# 102        6.3          2.9        5.6          1.8  Iris-virginica
# 103        6.5          3.0        5.8          2.2  Iris-virginica
# 104        7.6          3.0        6.6          2.1  Iris-virginica
# 105        4.9          2.5        4.5          1.7  Iris-virginica
# 106        7.3          2.9        6.3          1.8  Iris-virginica
# 107        6.7          2.5        5.8          1.8  Iris-virginica
# 108        7.2          3.6        6.1          2.5  Iris-virginica
# 109        6.5          3.2        5.1          2.0  Iris-virginica
# 110        6.4          2.7        5.3          1.9  Iris-virginica
# 111        6.8          3.0        5.5          2.1  Iris-virginica
# ...

# %%
m_setosa_s_len, m_setosa_s_width, m_setosa_p_len, m_setosa_p_width = df_setosa.mean()
sd_setosa_s_len, sd_setosa_s_width, sd_setosa_p_len, sd_setosa_p_width = df_setosa.std()

m_versi_s_len, m_versi_s_width, m_versi_p_len, m_versi_p_width = df_versicolor.mean()
sd_versi_s_len, sd_versi_s_width, sd_versi_p_len, sd_versi_p_width = df_versicolor.std()

m_vg_s_len, m_vg_s_width, m_vg_p_len, m_vg_p_width = df_virginica.mean()
sd_vg_s_len, sd_vg_s_width, sd_vg_p_len, sd_vg_p_width = df_virginica.std()

# %%
m_setosa_s_len, m_setosa_s_width, m_setosa_p_len, m_setosa_p_width
# Out:
# (5.004081632653061, 3.416326530612245, 1.4653061224489796, 0.2448979591836734)

# %%
m_versi_s_len, m_versi_s_width, m_versi_p_len, m_versi_p_width
# Out:
# (5.936, 2.7700000000000005, 4.26, 1.3259999999999998)

# %%
m_vg_s_len, m_vg_s_width, m_vg_p_len, m_vg_p_width
# Out:
# (6.587999999999998, 2.9739999999999998, 5.552, 2.026)

# %%
sd_setosa_s_len, sd_setosa_s_width, sd_setosa_p_len, sd_setosa_p_width
# Out:
# (0.3558787151038194,
#  0.3847872457473038,
#  0.17506072804430284,
#  0.10813036978919616)

# %%
sd_versi_s_len, sd_versi_s_width, sd_versi_p_len, sd_versi_p_width
# Out:
# (0.5161711470638635,
#  0.3137983233784114,
#  0.46991097723995806,
#  0.197752680004544)

# %%
sd_vg_s_len, sd_vg_s_width, sd_vg_p_len, sd_vg_p_width
# Out:
# (0.635879593274432,
#  0.3224966381726376,
#  0.5518946956639835,
#  0.27465005563666733)

# %% [markdown]
# ### a. Signal-to-noise ratio

# %%
def calculate_SNR(m_a, m_b, m_c, sd_a, sd_b, sd_c):
    return ((abs(m_a - m_b - m_c)) / (sd_a + sd_b + sd_c))

# %%
SNR_s_len = calculate_SNR(m_setosa_s_len, m_versi_s_len, m_vg_s_len, sd_setosa_s_len, sd_versi_s_len
                           , sd_vg_s_len)
SNR_s_len

# %%
SNR_s_width = calculate_SNR(m_setosa_s_width, m_versi_s_width, m_vg_s_width, sd_setosa_s_width, sd_versi_s_width, sd_vg_s_width)
SNR_s_width

# %%
SNR_p_len = calculate_SNR(m_setosa_p_len, m_versi_p_len, m_vg_p_len, sd_setosa_p_len, sd_versi_p_len, sd_vg_p_len)
SNR_p_len

# %%
SNR_p_width = calculate_SNR(m_setosa_p_width, m_versi_p_width, m_vg_p_width, sd_setosa_p_width, sd_versi_p_width, 
                            sd_vg_p_width)
SNR_p_width

# %% [markdown]
# Since signal-to-ratio of "petal length" attribute is larger, "Petal length" is a good feature for classification. "Petal width" has the second largest signal-to-noise ratio. Thus petal length and width are the two best features for classification.

# %% [markdown]
# ### Two tailed t-test

# %% [markdown]
# Looking at the numbers (mean and standard deviation) above for each attribute for different classes, Virginica and Versicolor classes seems to have mean and standard deviation closer than for Virginica and Setosa. So, we need to find an attribute which is a good distinguisher between Setosa and Virginica.
#
#
# I have implemented t-test calculations and also using Scipy.stats's ttest_ind for cross checking the t-value.
#
# Even though distinguishing Setosa from Virginica (and vice-versa) is most important I wanted to test for combinations of the classes.

# %%
def calculate_t(n_a, n_b, m_a, m_b, sd_a, sd_b):
    return (((m_a - m_b )) / math.sqrt(((sd_a * sd_a)/n_a) + ((sd_b * sd_b)/n_b)))

# %% [markdown]
# #### Setosa - Virginica

# %%
degree_of_freedom = len(df_setosa) + len(df_virginica) - 2
degree_of_freedom
# Out:
# 97

# %% [markdown]
# From t-table two tailed, for p=0.05 and degree_of_freedom = 95; t_critical = 1.980

# %%
t_calculated = calculate_t(len(df_setosa), len(df_virginica), m_setosa_s_len, m_vg_s_len, sd_setosa_s_len, sd_vg_s_len)


print('t calculated = '+str(t_calculated))


t2, p2 = stats.ttest_ind(df_setosa['sepal_len'],df_virginica['sepal_len'],equal_var=False)
print("t from stats = " + str(t2))
# Out:
# t calculated = -15.332718547400724
# t from stats = -15.332718547400717

# %%
t_calculated = calculate_t(len(df_setosa), len(df_virginica), m_setosa_s_width, m_vg_s_width, sd_setosa_s_width, sd_vg_s_width)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_setosa['sepal_width'],df_virginica['sepal_width'],equal_var=False)
print("t from stats = " + str(t2))
# Out:
# t calculated = 6.19275443348811
# t from stats = 6.192754433488112

# %%
t_calculated = calculate_t(len(df_setosa), len(df_virginica), m_setosa_p_len, m_vg_p_len, sd_setosa_p_len, sd_vg_p_len)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_setosa['petal_len'],df_virginica['petal_len'],equal_var=False)
print("t from stats= " + str(t2))
# Out:
# t calculated = -49.86299087875106
# t from stats= -49.862990878751084

# %%
t_calculated = calculate_t(len(df_setosa), len(df_virginica), m_setosa_p_width, m_vg_p_width, sd_setosa_p_width, sd_vg_p_width)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_setosa['petal_width'],df_virginica['petal_width'],equal_var=False)
print("t from stats= " + str(t2))
# Out:
# t calculated = -42.6097440893941
# t from stats= -42.60974408939409

# %% [markdown]
# Between class Setosa and Virginica, null hypothesis is that the classes are normally distributed and have equal variance. For all the attributes except Sepal width the hypothesis holds true. For Sepal width, t > t_critical thus making the hypothesis false. Hence, sepal width would be a good predictor between classes Setosa and Virginica.

# %% [markdown]
# #### Setosa - Versicolor

# %%
degree_of_freedom = len(df_setosa) + len(df_versicolor) - 2
degree_of_freedom
# Out:
# 97

# %% [markdown]
# From t-table two tailed, for p=0.05 and degree_of_freedom = 97; t_critical = 1.980

# %%
t_calculated = calculate_t(len(df_setosa), len(df_versicolor), m_setosa_s_len, m_versi_s_len, sd_setosa_s_len, sd_versi_s_len)


print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_setosa['sepal_len'],df_versicolor['sepal_len'],equal_var=False)
print("t from stats= " + str(t2))
# Out:
# t calculated = -10.47605955327841
# t from stats= -10.476059553278409

# %%
t_calculated = calculate_t(len(df_setosa), len(df_versicolor), m_setosa_s_width, m_versi_s_width, sd_setosa_s_width, sd_versi_s_width)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_setosa['sepal_width'],df_versicolor['sepal_width'],equal_var=False)
print("t from stats= " + str(t2))
# Out:
# t calculated = 9.148633361620911
# t from stats= 9.148633361620917

# %%
t_calculated = calculate_t(len(df_setosa), len(df_versicolor), m_setosa_p_len, m_versi_p_len, sd_setosa_p_len, sd_versi_p_len)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_setosa['petal_len'],df_versicolor['petal_len'],equal_var=False)
print("t from stats= " + str(t2))
# Out:
# t calculated = -39.35891728832079
# t from stats= -39.3589172883208

# %%
t_calculated = calculate_t(len(df_setosa), len(df_versicolor), m_setosa_p_width, m_versi_p_width, sd_setosa_p_width, sd_versi_p_width)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_setosa['petal_width'],df_versicolor['petal_width'],equal_var=False)
print("t from stat= " + str(t2))
# Out:
# t calculated = -33.83837360703361
# t from stat= -33.8383736070336

# %% [markdown]
# Between class Setosa and Versicolor, null hypothesis is that the classes are normally distributed and have equal variance. For all the attributes except Sepal width the hypothesis holds true since t < t_criticial. For Sepal width, t > t_critical thus making the hypothesis false. Hence, sepal width would be a good predictor between classes Setosa and Versicolor.

# %% [markdown]
# #### Virginica - Versicolor

# %%
degree_of_freedom = len(df_virginica) + len(df_versicolor) - 2
degree_of_freedom
# Out:
# 98

# %% [markdown]
# From t-table two tailed, for p=0.05 and degree_of_freedom = 98; t_critical = 1.980

# %%
t_calculated = calculate_t(len(df_virginica), len(df_versicolor), m_vg_s_len, m_versi_s_len, sd_vg_s_len, sd_versi_s_len)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_virginica['sepal_len'],df_versicolor['sepal_len'])
print("t from stats= " + str(t2))
# Out:
# t calculated = 5.629165259719802
# t from stats= 5.629165259719801

# %%
t_calculated = calculate_t(len(df_virginica), len(df_versicolor), m_vg_s_width, m_versi_s_width, sd_vg_s_width, sd_versi_s_width)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_virginica['sepal_width'],df_versicolor['sepal_width'],equal_var=False)
print("t from stats= " + str(t2))
# Out:
# t calculated = 3.2057607502218106
# t from stats= 3.2057607502218186

# %%
t_calculated = calculate_t(len(df_virginica), len(df_versicolor), m_vg_p_len, m_versi_p_len, sd_vg_p_len, sd_versi_p_len)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_virginica['petal_len'],df_versicolor['petal_len'],equal_var=False)
print("t from stats= " + str(t2))
# Out:
# t calculated = 12.603779441384976
# t from stats= 12.603779441384987

# %%
t_calculated = calculate_t(len(df_virginica), len(df_versicolor), m_vg_p_width, m_versi_p_width, sd_vg_p_width, sd_versi_p_width)

print('t calculated = '+str(t_calculated))

t2, p2 = stats.ttest_ind(df_virginica['petal_width'],df_versicolor['petal_width'],equal_var=False)
print("t from stats= " + str(t2))
# Out:
# t calculated = 14.62536704741014
# t from stats= 14.625367047410148

# %% [markdown]
# Between class Virginica and Versicolor, null hypothesis is that the classes are normally distributed and have equal variance. For all the attributes t > t_critical thus making the hypothesis false. Amongst all Petal width would be the correct attribute predictor.

# %% [markdown]
# ### Relief

# %%
def calculate_distance(obj1, obj2):
    sum = 0
    for i in range(0, 4):
        sum = sum + pow((obj1[i]-obj2[i]), 2)
    return math.sqrt(sum)

# %% [markdown]
# This function calculates distance from the given object to all the other objects in the dtaabase and returns the closest object of the same class (near hit) and closest object of the different class (near miss).

# %%
def process_obj(obj):
    obj_label=[]
    obj1 = obj[:-1]
    obj_label.append(obj[-1])
    
    distance = df_iris.apply(lambda x:sqrt(calculate_distance(x.values.tolist()[0:4],obj1)),axis=1)
    df_iris['distance'] = distance
    
    df_sorted = df_iris.sort_values("distance").copy().reset_index(drop=True)
    
    tmp = df_iris.groupby("label").apply(lambda x:x.sort_values("distance").head(2))
    near_hit = list(tmp[tmp.label==obj[-1]].values[1])
    
    df_near_miss = df_iris.loc[[df_iris.loc[~df_iris.label.isin(obj_label), 'distance'].idxmin()]]
    near_miss = df_near_miss.values.tolist()
    
    return near_hit, near_miss[0]

# %%
obj1 = [4.3,3.0,1.1,0.1,'Iris-setosa']
near_hit, near_miss = process_obj(obj1)
near_hit, near_miss
# Out:
# ([4.4, 3.0, 1.3, 0.2, 'Iris-setosa', 0.49492320038397675],
#  [5.1, 2.5, 3.0, 1.1, 'Iris-versicolor', 1.531407156804393])

# %% [markdown]
# Range for all the columns

# %%
range_sepal_len = df_iris["sepal_len"].max() - df_iris["sepal_len"].min()
range_sepal_width = df_iris["sepal_width"].max() - df_iris["sepal_width"].min()

range_petal_len = df_iris["petal_len"].max() - df_iris["petal_len"].min()
range_petal_width = df_iris["petal_width"].max() - df_iris["petal_width"].min()

range_sepal_len, range_sepal_width, range_petal_len, range_petal_width
# Out:
# (3.6000000000000005, 2.4000000000000004, 5.9, 2.4)

# %% [markdown]
# Update weights

# %%
W1 = 0 + pow(((obj1[0]-near_hit[0])/range_sepal_len),2) + pow(((obj1[0]-near_miss[0])/range_sepal_len),2)
W2 = 0 + pow(((obj1[1]-near_hit[1])/range_sepal_width),2) + pow(((obj1[1]-near_miss[1])/range_sepal_width),2)

W3 = 0 + pow(((obj1[2]-near_hit[2])/range_petal_len),2) + pow(((obj1[2]-near_miss[2])/range_petal_len),2)
W4 = 0 + pow(((obj1[3]-near_hit[3])/range_petal_width),2) + pow(((obj1[3]-near_miss[3])/range_petal_width),2)

# %%
W1, W2, W3, W4
# Out:
# (0.05015432098765429,
#  0.04340277777777777,
#  0.10485492674518815,
#  0.17534722222222224)

# %%
obj1 = [6.2,2.2,4.5,1.5,'Iris-versicolor']
near_hit, near_miss = process_obj(obj1)
near_hit, near_miss
# Out:
# ([6.3, 2.3, 4.4, 1.3, 'Iris-versicolor', 0.5143686723610398],
#  [6.0, 2.2, 5.0, 1.5, 'Iris-virginica', 0.7338368215846426])

# %%
W1 = W1 + pow(((obj1[0]-near_hit[0])/range_sepal_len),2) + pow(((obj1[0]-near_miss[0])/range_sepal_len),2)
W2 = W2 + pow(((obj1[1]-near_hit[1])/range_sepal_width),2) + pow(((obj1[1]-near_miss[1])/range_sepal_width),2)

W3 = W3 + pow(((obj1[2]-near_hit[2])/range_petal_len),2) + pow(((obj1[2]-near_miss[2])/range_petal_len),2)
W4 = W4 + pow(((obj1[3]-near_hit[3])/range_petal_width),2) + pow(((obj1[3]-near_miss[3])/range_petal_width),2)

# %%
W1, W2, W3, W4
# Out:
# (0.007716049382716046,
#  0.0034722222222221964,
#  0.0149382361390405,
#  0.013888888888888883)

# %% [markdown]
# If we select threshold = 0.01, then petal length and petal width are the best predicitve attributes.
